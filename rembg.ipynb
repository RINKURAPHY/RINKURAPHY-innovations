# %%
# !pip install rembg
# Out:
# Requirement already satisfied: rembg in c:\users\jose\anaconda3\lib\site-packages (2.0.60)
# Requirement already satisfied: jsonschema in c:\users\jose\anaconda3\lib\site-packages (from rembg) (4.19.2)
# Requirement already satisfied: numpy in c:\users\jose\anaconda3\lib\site-packages (from rembg) (1.26.4)
# Requirement already satisfied: opencv-python-headless in c:\users\jose\anaconda3\lib\site-packages (from rembg) (4.10.0.84)
# Requirement already satisfied: pillow in c:\users\jose\anaconda3\lib\site-packages (from rembg) (10.3.0)
# Requirement already satisfied: pooch in c:\users\jose\anaconda3\lib\site-packages (from rembg) (1.8.2)
# Requirement already satisfied: pymatting in c:\users\jose\anaconda3\lib\site-packages (from rembg) (1.1.13)
# Requirement already satisfied: scikit-image in c:\users\jose\anaconda3\lib\site-packages (from rembg) (0.23.2)
# Requirement already satisfied: scipy in c:\users\jose\anaconda3\lib\site-packages (from rembg) (1.13.1)
# Requirement already satisfied: tqdm in c:\users\jose\anaconda3\lib\site-packages (from rembg) (4.66.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jose\anaconda3\lib\site-packages (from jsonschema->rembg) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jose\anaconda3\lib\site-packages (from jsonschema->rembg) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jose\anaconda3\lib\site-packages (from jsonschema->rembg) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jose\anaconda3\lib\site-packages (from jsonschema->rembg) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\jose\anaconda3\lib\site-packages (from pooch->rembg) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jose\anaconda3\lib\site-packages (from pooch->rembg) (23.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jose\anaconda3\lib\site-packages (from pooch->rembg) (2.32.2)
# Requirement already satisfied: numba!=0.49.0 in c:\users\jose\anaconda3\lib\site-packages (from pymatting->rembg) (0.59.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\jose\anaconda3\lib\site-packages (from scikit-image->rembg) (3.2.1)
# Requirement already satisfied: imageio>=2.33 in c:\users\jose\anaconda3\lib\site-packages (from scikit-image->rembg) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\jose\anaconda3\lib\site-packages (from scikit-image->rembg) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\jose\anaconda3\lib\site-packages (from scikit-image->rembg) (0.4)
# Requirement already satisfied: colorama in c:\users\jose\anaconda3\lib\site-packages (from tqdm->rembg) (0.4.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\jose\anaconda3\lib\site-packages (from numba!=0.49.0->pymatting->rembg) (0.42.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jose\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->rembg) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jose\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->rembg) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jose\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->rembg) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jose\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->rembg) (2024.8.30)

# %%
pip install onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in c:\users\jose\anaconda3\lib\site-packages (1.20.1)
# Requirement already satisfied: coloredlogs in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (24.3.25)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (1.26.4)
# Requirement already satisfied: packaging in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (23.2)
# Requirement already satisfied: protobuf in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (1.12)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\jose\anaconda3\lib\site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jose\anaconda3\lib\site-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\jose\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime) (3.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in c:\users\jose\anaconda3\lib\site-packages (1.20.1)
# Requirement already satisfied: coloredlogs in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (24.3.25)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (1.26.4)
# Requirement already satisfied: packaging in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (23.2)
# Requirement already satisfied: protobuf in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in c:\users\jose\anaconda3\lib\site-packages (from onnxruntime) (1.12)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\jose\anaconda3\lib\site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jose\anaconda3\lib\site-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\jose\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime) (3.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from rembg import remove
from PIL import Image
input_path='Screenshot (199) .jpg'
output_path='Screenshot (199).png'
inp=Image.open(input_path)
output=remove(inp)
output.save(output_path)
Image.open(output_path)
# Out:
# Downloading data from 'https://github.com/danielgatis/rembg/releases/download/v0.0.0/u2net.onnx' to file 'C:\Users\JOSE\.u2net\u2net.onnx'.
# 100%|#######################################| 176M/176M [00:00<00:00, 87.6GB/s]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1366x729>
